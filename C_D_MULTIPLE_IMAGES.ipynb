# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **CSV CONTAINING COLOURS**

# %%
col_names=['color','color_name','hex_code','R','G','B']
color_csv=pd.read_csv("colors.csv",names=col_names,header=None)
color_csv.head()
# Out:
#                   color             color_name hex_code    R    G    B
# 0    air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 1   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 2  air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 3       alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 4            alice_blue             Alice Blue  #f0f8ff  240  248  255

# %% [markdown]
# **READING AND RESIZING 1st IMAGE**

# %%
image_1=cv2.imread("pic1.jpg")
image_1=cv2.resize(image_1,(1000,800))
plt.imshow(image_1)

# %% [markdown]
# **1st IMAGE IN RGB FORMAT**

# %%
org_image_1=cv2.cvtColor(image_1,cv2.COLOR_BGR2RGB)
plt.imshow(org_image_1)

# %% [markdown]
# **READING AND RESIZING 2nd IMAGE**

# %%
image_2=cv2.imread("pic2.jpg")
image_2=cv2.resize(image_2,(1000,800))
plt.imshow(image_2)

# %% [markdown]
# **2nd IMAGE IN RGB FORMAT**

# %%
org_image_2=cv2.cvtColor(image_2,cv2.COLOR_BGR2RGB)
plt.imshow(org_image_2)

# %% [markdown]
# **READING AND RESIZING 3rd IMAGE**

# %%
image_3=cv2.imread("pic3.jpg")
image_3=cv2.resize(image_3,(1000,800))
plt.imshow(image_3)

# %% [markdown]
# **3rd IMAGE IN RGB FORMAT**

# %%
org_image_3=cv2.cvtColor(image_3,cv2.COLOR_BGR2RGB)
plt.imshow(org_image_3)

# %% [markdown]
# **SETTING INITIAL MOUSE ACTIVITY TO FALSE**

# %%
clicked=False

# %% [markdown]
# **FUNCTION CHECKING FOR CLICK AND FINDING THE BGR VALUE AT THAT CO-ORDINATE OF CLICK**

# %%
def draw_function(event,x,y,flags,params):
    if(event== cv2.EVENT_LBUTTONDBLCLK):
        global xcor,ycor,b,g,r,clicked
        clicked=True
        xcor=x
        ycor=y
        b,g,r=image[ycor,xcor]
        b=int(b)
        g=int(g)
        r=int(r)

# %% [markdown]
# **FUNCTION FINDING COLOUR IN CSV USING ABSOLUTE VALUE OF BGR**

# %%
def colour_name(R,G,B):
    mini = 1000
    for i in range(len(color_csv)):
        diff = abs(R - int(color_csv.loc[i,'R'])) + abs(G - int(color_csv.loc[i,'G'])) + abs(B - int(color_csv.loc[i,'B']))
        if diff <= mini:
            mini = diff
            colour = color_csv.loc[i, 'color_name']
    return colour

# %% [markdown]
# **FINDING COLOURS IN IMAGE 1**

# %%
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_function)

# %%
while True:
    image=image_1
    cv2.imshow('image', image)
    if clicked: 
        cv2.rectangle(image, (20,20), (600,60), (b,g,r), -1)
        text = colour_name(r,g,b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
        cv2.putText(image, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)
        if r+g+b >=600:
            cv2.putText(image, text, (50,50), 2,0.8, (0,0,0),2,cv2.LINE_AA)

    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()

# %% [markdown]
# **FINDING COLOURS IN IMAGE 2**

# %%
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_function)

# %%
while True:
    image=image_2
    cv2.imshow('image', image)
    if clicked: 
        cv2.rectangle(image, (20,20), (600,60), (b,g,r), -1)
        text = colour_name(r,g,b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
        cv2.putText(image, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)
        if r+g+b >=600:
            cv2.putText(image, text, (50,50), 2,0.8, (0,0,0),2,cv2.LINE_AA)

    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()

# %% [markdown]
# **FINDING COLOURS IN IMAGE 3**

# %%
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_function)

# %%
while True:
    image=image_3
    cv2.imshow('image', image)
    if clicked: 
        cv2.rectangle(image, (20,20), (600,60), (b,g,r), -1)
        text = colour_name(r,g,b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
        cv2.putText(image, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)
        if r+g+b >=600:
            cv2.putText(image, text, (50,50), 2,0.8, (0,0,0),2,cv2.LINE_AA)

    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()
